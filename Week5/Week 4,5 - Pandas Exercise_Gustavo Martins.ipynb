# %% [markdown]
# ![](logo.png)

# %% [markdown]
# # <font color='red'>Introduction to Pandas Exercise</font>
#
# The last two weeks focused on the Pandas library, specifically input of files to dataframes, indexing a selecting subsets of data, merging and joining, and output of dataframes to various files. This exercise is designed to review the materials coverd in the Week 4 and 5 lectures.

# %% [markdown]
# 1. Import Pandas, Numpy and OS libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 2. Read in the peanut_lines CSV file as **peanut_lines** (Use encoding='ISO-8859-1')

# %%
# Importing peanut_lines.csv
peanut_lines = pd.read_csv('peanut_lines.csv', encoding='ISO-8859-1')

# %% [markdown]
# 3. Check the head of the files

# %%
peanut_lines.head(10) #Asking the first 10 rows
# Out:
#     NC_Accession                              Identity or Parentage  \
# 0  ACI WT09-0761                                      ACI WT09-0761
# 1  ACI WT11-0351                                      ACI WT11-0351
# 2  ACI WT12-0226                                      ACI WT12-0226
# 3  ACI WT12-0419                                      ACI WT12-0419
# 4  ACI WT12-0420                                      ACI WT12-0420
# 5  ACI WT12-0433                                      ACI WT12-0433
# 6         Bailey                                 NC 12C*2 / N96076L
# 7      Bailey II  Bailey /4/ X07016, Bailey // X05027, Bailey / ...
# 8       Brantley                                           Brantley
# 9         CHAMPS                                             CHAMPS
#
#                      Pedigree    FAG
# 0                         NaN  Check
# 1                         NaN  ol ol
# 2                         NaN  ol ol
# 3                         NaN  Check
# 4                         NaN  ol ol
# 5                         NaN  Check
# 6  BC1F1-06-01-S-03-S-05: F09    + +
# 7  BC3F1-02-01-S-02-S-02: F09  ol ol
# 8                         NaN  ol ol
# 9                         NaN    + +

# %% [markdown]
# 4. Use the .info() method to find out how many peanut_lines are in the dataframe
#
#     **Bonus: Print the total number of entries?

# %%
peanut_lines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 4 columns):
# NC_Accession             466 non-null object
# Identity or Parentage    466 non-null object
# Pedigree                 409 non-null object
# FAG                      466 non-null object
# dtypes: object(4)
# memory usage: 14.6+ KB

# %%
print(peanut_lines.shape[0]) #shape [0 = rows,1 = columns]
# Out:
# 466

# %% [markdown]
# 5. Read in the peanut_yield text file as **peanut_yield** (Use encoding='ISO-8859-1')

# %%
# Importing peanut_yield.txt
peanut_yield = pd.read_csv('peanut_yield.txt', sep ='\t', encoding='ISO-8859-1')

# %% [markdown]
# 6. Check the column names of peanut_yield

# %%
peanut_yield.columns
# Out:
# Index(['Year', 'Location', 'Name', 'Label', 'NC_Accession', 'Plot_Yield',
#        'Yield'],
#       dtype='object')

# %% [markdown]
# 7. Using 'NC_Accession', merge (or join) the two dataframes together keeping the entirety of the peanut_yield data. Name the new dataframe **peanut_data**

# %%
peanut_lines.sort_values('NC_Accession', inplace=True)
peanut_lines.head(20)
# Out:
#      NC_Accession                              Identity or Parentage  \
# 0   ACI WT09-0761                                      ACI WT09-0761
# 1   ACI WT11-0351                                      ACI WT11-0351
# 2   ACI WT12-0226                                      ACI WT12-0226
# 3   ACI WT12-0419                                      ACI WT12-0419
# 4   ACI WT12-0420                                      ACI WT12-0420
# 5   ACI WT12-0433                                      ACI WT12-0433
# 6          Bailey                                 NC 12C*2 / N96076L
# 7       Bailey II  Bailey /4/ X07016, Bailey // X05027, Bailey / ...
# 8        Brantley                                           Brantley
# 9          CHAMPS                                             CHAMPS
# 10          Emery                              N03079FT*2 / Brantley
# 14     FloRun 107                                         FloRun 107
# 15     FloRun 157                                         FloRun 157
# 16     FloRun 331                                         FloRun 331
# 13     FloriGiant                                         FloriGiant
# 11  Florida Fancy                                      Florida Fancy
# 12     Florida-07                                         Florida-07
# 17  Georgia Green                                      Georgia Green
# 18    Georgia-06G                                        Georgia-06G
# 19    Georgia-07W                                        Georgia-07W
#
#                         Pedigree    FAG
# 0                            NaN  Check
# 1                            NaN  ol ol
# 2                            NaN  ol ol
# 3                            NaN  Check
# 4                            NaN  ol ol
# 5                            NaN  Check
# 6     BC1F1-06-01-S-03-S-05: F09    + +
# 7     BC3F1-02-01-S-02-S-02: F09  ol ol
# 8                            NaN  ol ol
# 9                            NaN    + +
# 10  BC1F1-03-01-01-02-02-01: F08  ol ol
# 14                           NaN  ol ol
# 15                           NaN  ol ol
# 16                           NaN  ol ol
# 13                           NaN    + +
# 11                           NaN  ol ol
# 12                           NaN  ol ol
# 17                           NaN    + +
# 18                           NaN    + +
# 19                           NaN    + +

# %%
peanut_yield.sort_values('NC_Accession', inplace=True)
peanut_yield.head(20)
# Out:
#     Year Location Name                             Label   NC_Accession  \
# 0   2014      LEW  ATP  Advanced Testing Program - Yield  ACI WT09-0761
# 1   2014      RMT  ATP  Advanced Testing Program - Yield  ACI WT09-0761
# 2   2014      WHI  ATP  Advanced Testing Program - Yield  ACI WT09-0761
# 3   2015      LEW  ATP  Advanced Testing Program - Yield  ACI WT11-0351
# 4   2015      RMT  ATP  Advanced Testing Program - Yield  ACI WT11-0351
# 5   2015      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0226
# 6   2015      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0226
# 7   2014      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0419
# 8   2014      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0419
# 9   2014      WHI  ATP  Advanced Testing Program - Yield  ACI WT12-0419
# 10  2015      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0420
# 11  2015      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0420
# 14  2014      WHI  ATP  Advanced Testing Program - Yield  ACI WT12-0433
# 13  2014      RMT  ATP  Advanced Testing Program - Yield  ACI WT12-0433
# 12  2014      LEW  ATP  Advanced Testing Program - Yield  ACI WT12-0433
# 35  2017      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 31  2015      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 32  2016      LEW  ATP  Advanced Testing Program - Yield         Bailey
# 33  2016      RMT  ATP  Advanced Testing Program - Yield         Bailey
# 34  2016      WHI  ATP  Advanced Testing Program - Yield         Bailey
#
#     Plot_Yield  Yield
# 0          9.0   2733
# 1         10.2   3085
# 2         10.2   3085
# 3         15.3   4632
# 4         10.7   3226
# 5         13.6   4104
# 6         15.1   4572
# 7          6.6   1993
# 8          8.1   2457
# 9          8.1   2457
# 10        11.3   3414
# 11        16.3   4932
# 14        11.0   3316
# 13        11.0   3316
# 12        12.2   3687
# 35        16.0   4841
# 31        11.8   3582
# 32         8.5   2586
# 33         7.5   2262
# 34         9.9   2990

# %%
peanut_data = pd.merge(peanut_lines, peanut_yield, on='NC_Accession', how='right')
peanut_data.head(20)
# Out:
#      NC_Accession Identity or Parentage                    Pedigree    FAG  \
# 0   ACI WT09-0761         ACI WT09-0761                         NaN  Check
# 1   ACI WT09-0761         ACI WT09-0761                         NaN  Check
# 2   ACI WT09-0761         ACI WT09-0761                         NaN  Check
# 3   ACI WT11-0351         ACI WT11-0351                         NaN  ol ol
# 4   ACI WT11-0351         ACI WT11-0351                         NaN  ol ol
# 5   ACI WT12-0226         ACI WT12-0226                         NaN  ol ol
# 6   ACI WT12-0226         ACI WT12-0226                         NaN  ol ol
# 7   ACI WT12-0419         ACI WT12-0419                         NaN  Check
# 8   ACI WT12-0419         ACI WT12-0419                         NaN  Check
# 9   ACI WT12-0419         ACI WT12-0419                         NaN  Check
# 10  ACI WT12-0420         ACI WT12-0420                         NaN  ol ol
# 11  ACI WT12-0420         ACI WT12-0420                         NaN  ol ol
# 12  ACI WT12-0433         ACI WT12-0433                         NaN  Check
# 13  ACI WT12-0433         ACI WT12-0433                         NaN  Check
# 14  ACI WT12-0433         ACI WT12-0433                         NaN  Check
# 15         Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 16         Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 17         Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 18         Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
# 19         Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09    + +
#
#     Year Location Name                             Label  Plot_Yield  Yield
# 0   2014      LEW  ATP  Advanced Testing Program - Yield         9.0   2733
# 1   2014      RMT  ATP  Advanced Testing Program - Yield        10.2   3085
# 2   2014      WHI  ATP  Advanced Testing Program - Yield        10.2   3085
# 3   2015      LEW  ATP  Advanced Testing Program - Yield        15.3   4632
# 4   2015      RMT  ATP  Advanced Testing Program - Yield        10.7   3226
# 5   2015      LEW  ATP  Advanced Testing Program - Yield        13.6   4104
# 6   2015      RMT  ATP  Advanced Testing Program - Yield        15.1   4572
# 7   2014      LEW  ATP  Advanced Testing Program - Yield         6.6   1993
# 8   2014      RMT  ATP  Advanced Testing Program - Yield         8.1   2457
# 9   2014      WHI  ATP  Advanced Testing Program - Yield         8.1   2457
# 10  2015      LEW  ATP  Advanced Testing Program - Yield        11.3   3414
# 11  2015      RMT  ATP  Advanced Testing Program - Yield        16.3   4932
# 12  2014      WHI  ATP  Advanced Testing Program - Yield        11.0   3316
# 13  2014      RMT  ATP  Advanced Testing Program - Yield        11.0   3316
# 14  2014      LEW  ATP  Advanced Testing Program - Yield        12.2   3687
# 15  2017      LEW  ATP  Advanced Testing Program - Yield        16.0   4841
# 16  2015      RMT  ATP  Advanced Testing Program - Yield        11.8   3582
# 17  2016      LEW  ATP  Advanced Testing Program - Yield         8.5   2586
# 18  2016      RMT  ATP  Advanced Testing Program - Yield         7.5   2262
# 19  2016      WHI  ATP  Advanced Testing Program - Yield         9.9   2990

# %% [markdown]
# 8. What is the average yield in 2017?

# %%
peanut_data.head(5)
# Out:
#     NC_Accession Identity or Parentage Pedigree    FAG  Year Location Name  \
# 0  ACI WT09-0761         ACI WT09-0761      NaN  Check  2014      LEW  ATP
# 1  ACI WT09-0761         ACI WT09-0761      NaN  Check  2014      RMT  ATP
# 2  ACI WT09-0761         ACI WT09-0761      NaN  Check  2014      WHI  ATP
# 3  ACI WT11-0351         ACI WT11-0351      NaN  ol ol  2015      LEW  ATP
# 4  ACI WT11-0351         ACI WT11-0351      NaN  ol ol  2015      RMT  ATP
#
#                               Label  Plot_Yield  Yield
# 0  Advanced Testing Program - Yield         9.0   2733
# 1  Advanced Testing Program - Yield        10.2   3085
# 2  Advanced Testing Program - Yield        10.2   3085
# 3  Advanced Testing Program - Yield        15.3   4632
# 4  Advanced Testing Program - Yield        10.7   3226

# %%
peanut_data.iloc[0,9]
# Out:
# 2733

# %%
peanut_data['Yield'][peanut_data['Year']==2017].mean()
# Out:
# 3981.6

# %% [markdown]
# 9. What was the aveerage yield of the top 10 lines tested in the peanut program?

# %%
peanut_data.groupby('NC_Accession').mean()['Yield'].sort_values(ascending=False).head(10).mean()
# Out:
# 5155.0666666666675

# %% [markdown]
# 10. What are the top 10 most commonly tested lines? Hint: value_counts()

# %%
peanut_data['NC_Accession'].value_counts().head(10)
# Out:
# N11028        34
# Wynne         26
# Emery         26
# Sullivan      26
# Sugg          26
# Bailey        26
# Bailey II     20
# N11020        20
# Florida-07    20
# N08085        18
# Name: NC_Accession, dtype: int64

# %% [markdown]
# 11. Create a dataframe that satisfy the following requirements
# <br>peanut lines = 'Bailey', 'Sullivan', 'Wynne', 'Emery', 'Bailey II', 'N14023'
# <br>location = 'LEW', 'RMT' #Lewiston and Rocky Mount
# <br>Dataframe = line_data

# %%
peanut_lines = ['Bailey','Sullivan','Wynne','Emery','Bailey II','N14023']
location = ['LEW', 'RMT']
line_data = peanut_data[(peanut_data['NC_Accession'].isin(peanut_lines)) & (peanut_data['Location'].isin(location))]
line_data.head(10)
# Out:
#    NC_Accession Identity or Parentage                    Pedigree  FAG  Year  \
# 15       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2017
# 16       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2015
# 17       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2016
# 18       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2016
# 20       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2018
# 21       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2017
# 23       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2018
# 24       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2014
# 27       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2015
# 28       Bailey    NC 12C*2 / N96076L  BC1F1-06-01-S-03-S-05: F09  + +  2010
#
#    Location Name                             Label  Plot_Yield  Yield
# 15      LEW  ATP  Advanced Testing Program - Yield        16.0   4841
# 16      RMT  ATP  Advanced Testing Program - Yield        11.8   3582
# 17      LEW  ATP  Advanced Testing Program - Yield         8.5   2586
# 18      RMT  ATP  Advanced Testing Program - Yield         7.5   2262
# 20      RMT  ATP  Advanced Testing Program - Yield        13.6   4104
# 21      RMT  ATP  Advanced Testing Program - Yield        14.8   4480
# 23      LEW  ATP  Advanced Testing Program - Yield        12.9   3915
# 24      RMT  ATP  Advanced Testing Program - Yield        12.1   3660
# 27      LEW  ATP  Advanced Testing Program - Yield        14.4   4342
# 28      LEW  ATP  Advanced Testing Program - Yield        11.7   3529

# %% [markdown]
# 12. Export the means of each line by location to an excel file called 'NCSU_release.xlsx'

# %%
line_data.groupby(['Location','NC_Accession']).mean()['Yield'].to_excel('NCSU_release.xlsx')
